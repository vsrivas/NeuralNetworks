# %%
import pandas as pd
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Activation
from keras.layers import GlobalAveragePooling1D
from keras.utils import np_utils
import tensorflow
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import optimizers

# %%
# %matplotlib inline
import numpy as np

from scipy.io import loadmat
import glob

# %% [markdown]
# ### Read EEG data based on the patient ID

# %% [markdown]
# #### Read patient ID

# %%
# path to the dataset
from pathlib import Path

path = 'C:/Vandana_Jan2022/PhD/Fall 2022/NeuralNetworks/Project/MAT_raw_50Hz'

# %%
# Read patient id into dataframe
label_df = pd.read_excel(path+'/Labels.xlsx')
label_df.head()
# Out:
#    EEG_ID  OUTCOME  SURVIVAL  NOValid  DIAGNOSTIC
# 0  VD_014        0         0        3           2
# 1  VD_018        0         0        4           3
# 2  VD_020        1         1        3           2
# 3  VD_034        1         1        4           3
# 4  VD_037        1         0        1           0

# %%
# convert the datatype of column EEG_ID and make a list of all ID's
id = label_df['EEG_ID'].astype(str).values.tolist()
#id

# %% [markdown]
# #### Read the EEG data from the matlab (.mat) files using patient id's

# %%
matfiles = []

# Read all files corresponding to the patient id and having "_1_50hz" in their name
for i in id:
    for fname in Path(path).glob(f"{i}_1_50hz.mat"):
        matfiles.append(loadmat(fname, struct_as_record=True))

# %%
'''Check for the data --- Each recording corresponds to one patient, the data is in the form of a dictionary whose key 
is the channel name and value is the recording. The recording has 20 - 26 channels'''
#matfiles[0]
# Out:
# 'Check for the data --- Each recording corresponds to one patient, the data is in the form of a dictionary whose key \nis the channel name and value is the recording. The recording has 20 - 26 channels'

# %% [markdown]
# #### PIck recordings for channels of interest, and remove headers from the dictionary

# %%
# header keys for removal from data dictionary
rem_list = ['__header__', '__version__', '__globals__']
 
# Remove multiple keys from dictionary
for i in range(len(matfiles)):
    for key in rem_list:
        del matfiles[i][key]

# %%
# data dictionary after removal of header
#matfiles[0]

# %%
# Capture first 2000 data points (40 seconds, sampling frequency= 50hz) for the 10 channels of interest
data = []

# Channels of interest - 7 
Ch = ['C3', 'C4','Fp1', 'Fp2', 'T7', 'T8', 'O1', 'O2','Cz', 'Fpz']

for i in matfiles:
    # print (i) 
    # Collect values for a given dict.
    vals = []
    for a_channel in Ch:
        value = i.get(a_channel)
        if value is not None:
            vals.append(value[:2000])
    # Now add to the results list
    data.append(vals)

# %%
len(data[0][0])
# Out:
# 2000

# %%
dataX = np.array(data, dtype=object)
dataX = np.squeeze(dataX)
dataX.shape
# Out:
# (274, 7, 2000)

# %%
dataX.resize(274, 2000, 7)
dataX.shape
# Out:
# (274, 2000, 7)

# %%
dataY = np.array(label_df['OUTCOME'][:274].values.tolist())

# %%
print(dataY.shape)
#print(testY.shape)
# Out:
# (274,)

# %%
dataX = np.asarray(dataX).astype(np.float32)

# %%
dataY = np.asarray(dataY).astype(np.float32)

# %% [markdown]
# ## Outcome classification function

# %%
learningrate = 0.0001
model = Sequential()

# Block 1
model.add(Conv1D(16, kernel_size=3,strides=1,
                 name="firstCV",use_bias=False,
                 kernel_initializer="glorot_uniform", input_shape= (2000,7)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv1D(16, kernel_size=3,strides=1, use_bias=False, kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_size = 4, strides=4))

# Block 2
model.add(Conv1D(32, kernel_size=3,kernel_initializer="glorot_uniform",
                 strides=1, use_bias = False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv1D(32, kernel_size=3,strides=1, use_bias = False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_size = 4, strides=4))

# Block 3
model.add(Conv1D(32, kernel_size=3,kernel_initializer="glorot_uniform",strides=1, use_bias = False))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv1D(32, kernel_size=3,strides=1, use_bias=False, name="lastCV")) # the name is used as referral for GradCAM
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_size = 4, strides=4))

# Global Average Pooling operation after the third block
model.add(GlobalAveragePooling1D())

# into a final single-neuron FC layer outputting the probability
model.add(Dense(1, activation='sigmoid'))

adam = optimizers.Adam(learning_rate=learningrate)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
hist_outcome = model.fit(dataX, dataY, epochs=50)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4984 - accuracy: 0.8029
# Epoch 2/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4925 - accuracy: 0.7993
# Epoch 3/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.4906 - accuracy: 0.8066
# Epoch 4/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4942 - accuracy: 0.8358
# Epoch 5/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.4878 - accuracy: 0.7993
# Epoch 6/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.4920 - accuracy: 0.8175
# Epoch 7/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4939 - accuracy: 0.7920
# Epoch 8/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.4759 - accuracy: 0.8139
# Epoch 9/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4807 - accuracy: 0.8029
# Epoch 10/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4738 - accuracy: 0.8321
# Epoch 11/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4724 - accuracy: 0.8139
# Epoch 12/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4631 - accuracy: 0.8394
# Epoch 13/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4645 - accuracy: 0.8248
# Epoch 14/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4659 - accuracy: 0.8285
# Epoch 15/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4551 - accuracy: 0.8394
# Epoch 16/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4649 - accuracy: 0.8248
# Epoch 17/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4591 - accuracy: 0.8394
# Epoch 18/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4520 - accuracy: 0.8467
# Epoch 19/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4557 - accuracy: 0.8613
# Epoch 20/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4465 - accuracy: 0.8285
# Epoch 21/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4509 - accuracy: 0.8504
# Epoch 22/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4466 - accuracy: 0.8504
# Epoch 23/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4422 - accuracy: 0.8577
# Epoch 24/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4400 - accuracy: 0.8577
# Epoch 25/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4428 - accuracy: 0.8577
# Epoch 26/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4343 - accuracy: 0.8540
# Epoch 27/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4399 - accuracy: 0.8431
# Epoch 28/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4390 - accuracy: 0.8504
# Epoch 29/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4272 - accuracy: 0.8467
# Epoch 30/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4234 - accuracy: 0.8540
# Epoch 31/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4262 - accuracy: 0.8577
# Epoch 32/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4164 - accuracy: 0.8613
# Epoch 33/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4170 - accuracy: 0.8504
# Epoch 34/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4054 - accuracy: 0.8796
# Epoch 35/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4109 - accuracy: 0.8577
# Epoch 36/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4112 - accuracy: 0.8723
# Epoch 37/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.4095 - accuracy: 0.8613
# Epoch 38/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4077 - accuracy: 0.8686
# Epoch 39/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.4007 - accuracy: 0.8723
# Epoch 40/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3977 - accuracy: 0.8577
# Epoch 41/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3911 - accuracy: 0.8577
# Epoch 42/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3896 - accuracy: 0.8796
# Epoch 43/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3813 - accuracy: 0.8796
# Epoch 44/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3801 - accuracy: 0.8869
# Epoch 45/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3800 - accuracy: 0.8759
# Epoch 46/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3869 - accuracy: 0.8832
# Epoch 47/50
# 9/9 [==============================] - 0s 52ms/step - loss: 0.3869 - accuracy: 0.8869
# Epoch 48/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3740 - accuracy: 0.9015
# Epoch 49/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.3796 - accuracy: 0.8869
# Epoch 50/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.3764 - accuracy: 0.8759

# %% [markdown]
# #### Visulaize loss and accuracy for training data

# %%
# plot loss
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
ax[0].plot(hist_outcome.history['loss'], color='red')
ax[0].set_title('Binary Cross Entropy Loss')
ax[0].set_xlabel("epoch")
ax[0].set_ylabel("loss")

 # plot accuracy
ax[1].set_title('Classification accuracy')
ax[1].plot(hist_outcome.history['accuracy'], color='green', label='train')
ax[1].set_xlabel("epoch")
ax[1].set_ylabel("accuracy")
fig.suptitle("Training error and accuracy in 50 epochs for outcome prediction", fontsize = 20)
fig.tight_layout()
fig.savefig("Outcome.png")
plt.show()

# %% [markdown]
# ## K-fold evaluation of outcome classification

# %%
# evaluate a model using k-fold cross-validation
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
def evaluate_model(dataX, dataY, n_splits=5):
    scores, histories = list(), list()
     # prepare cross validation
    skf = StratifiedKFold(n_splits, shuffle=True)
     # enumerate splits
    for train_ix, test_ix in skf.split(dataX, dataY):
     # define model
     #model = define_model()
     # select rows for train and test
         trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
     # fit model
         history = model.fit(trainX, trainY, epochs=50, verbose=0)
     # evaluate model
         _, acc = model.evaluate(testX, testY, verbose=0)
         print('> %.3f' % (acc * 100.0))
     # stores scores
         scores.append(acc)
         histories.append(history)
    return scores, histories

# %%
scores, histories = evaluate_model(dataX, dataY, n_splits=5)
# Out:
# > 60.000
# > 72.727
# > 90.909
# > 94.545
# > 96.296

# %%
print('Test loss:', scores) 
# print('Test accuracy:', scores[1])
# Out:
# Test loss: [0.6000000238418579, 0.7272727489471436, 0.9090909361839294, 0.9454545378684998, 0.9629629850387573]

# %%
import matplotlib.pyplot as plt
# plot diagnostic learning curves
def summarize_diagnostics(histories):
    for i in range(len(histories)):
 # plot loss
     fig, ax = plt.subplots(1, 2, figsize = (15, 4))
     ax[0].plot(histories[i].history['loss'], color='blue')
     ax[0].set_title('Binary Cross Entropy Loss')
     ax[0].set_xlabel("epoch")
     ax[0].set_ylabel("loss")

     # plot accuracy
     ax[1].set_title('Classification accuracy')
     ax[1].plot(histories[i].history['accuracy'], color='orange', label='train')
     ax[1].set_xlabel("epoch")
     ax[1].set_ylabel("accuracy")
     plt.show()

# %%
fig = summarize_diagnostics(histories)

# %%
fig

# %% [markdown]
# # Predicting Etiology

# %%
#Read the diagnostic labels 
dataY_D = np.array(label_df['DIAGNOSTIC'][:274].values.tolist())

# %%
dataY_D
# Out:
# array([2, 3, 2, 3, 0, 3, 3, 3, 2, 1, 1, 1, 0, 0, 0, 3, 0, 2, 3, 0, 0, 2,
#        3, 0, 0, 0, 0, 3, 3, 3, 2, 0, 3, 2, 3, 3, 1, 1, 3, 0, 0, 3, 3, 0,
#        3, 3, 3, 3, 2, 0, 0, 3, 3, 3, 3, 0, 0, 3, 0, 3, 0, 2, 3, 2, 1, 1,
#        0, 1, 2, 3, 3, 3, 3, 1, 3, 3, 1, 0, 1, 3, 3, 0, 0, 3, 3, 0, 0, 3,
#        3, 1, 1, 3, 3, 1, 3, 0, 0, 3, 0, 0, 3, 0, 2, 0, 0, 2, 2, 3, 0, 2,
#        0, 3, 1, 1, 0, 3, 0, 1, 0, 0, 3, 3, 2, 2, 3, 3, 0, 3, 3, 1, 2, 1,
#        0, 2, 2, 3, 1, 3, 0, 3, 2, 3, 0, 1, 1, 1, 1, 2, 0, 3, 3, 3, 3, 0,
#        2, 0, 1, 0, 2, 2, 0, 0, 2, 2, 0, 0, 1, 1, 1, 1, 2, 3, 1, 0, 0, 1,
#        1, 0, 1, 3, 3, 2, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 2, 3, 2, 0, 3, 2,
#        3, 3, 3, 0, 0, 1, 3, 1, 0, 3, 3, 0, 3, 0, 3, 0, 0, 3, 1, 3, 2, 1,
#        1, 3, 2, 0, 0, 3, 2, 2, 0, 3, 2, 0, 3, 3, 1, 1, 3, 3, 2, 0, 3, 3,
#        1, 0, 3, 0, 0, 2, 1, 3, 0, 1, 2, 3, 3, 2, 3, 2, 3, 0, 3, 2, 0, 1,
#        0, 0, 0, 0, 3, 3, 1, 2, 3, 3])

# %%
'''
Returns the same model architecture compiled and adjusted for the multi-class (etiology, 4 classes) setting.
'''
def compile_multi_class_TVGG_model(input_vars=(2000,7), learningrate = 0.0001, num_final_classes = 4):
    timeseries_windowsize = input_vars[0]
    num_channels = input_vars[1]
    model = Sequential()
    # Block 1
    model.add(Conv1D(16, kernel_size=3,strides=1,
                     name="firstCV",use_bias=False,
                     kernel_initializer="glorot_uniform", input_shape=(timeseries_windowsize,num_channels)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv1D(16, kernel_size=3,strides=1, use_bias=False, kernel_initializer="glorot_uniform"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size = 4, strides=4))

    # Block 2
    model.add(Conv1D(32, kernel_size=3,kernel_initializer="glorot_uniform",
                     strides=1, use_bias = False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv1D(32, kernel_size=3,strides=1, use_bias = False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size = 4, strides=4))

    # Block 3
    model.add(Conv1D(32, kernel_size=3,kernel_initializer="glorot_uniform",strides=1, use_bias = False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv1D(32, kernel_size=3,strides=1, use_bias=False, name="lastCV")) 
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size = 4, strides=4))

    # GAP into a single output layer
    model.add(GlobalAveragePooling1D())
    # num_classes neurons activated by softmax
    model.add(Dense(num_final_classes, activation='softmax'))
    
    adam = optimizers.Adam(learning_rate=learningrate)
    model.compile(loss='sparse_categorical_crossentropy', 
              optimizer=adam,  
                metrics=['accuracy'])
    return model

# %%
model1 = compile_multi_class_TVGG_model(input_vars=(2000,7), learningrate = 0.0001, num_final_classes = 4)

# %%
# model accuracy without cross validation
hist_etiology = model1.fit(dataX, dataY, epochs=50)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 2s 50ms/step - loss: 1.2247 - accuracy: 0.3759
# Epoch 2/50
# 9/9 [==============================] - 0s 45ms/step - loss: 1.1482 - accuracy: 0.3942
# Epoch 3/50
# 9/9 [==============================] - 0s 50ms/step - loss: 1.0899 - accuracy: 0.4562
# Epoch 4/50
# 9/9 [==============================] - 0s 48ms/step - loss: 1.0278 - accuracy: 0.5438
# Epoch 5/50
# 9/9 [==============================] - 0s 46ms/step - loss: 0.9883 - accuracy: 0.5547
# Epoch 6/50
# 9/9 [==============================] - 0s 45ms/step - loss: 0.9489 - accuracy: 0.5839
# Epoch 7/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.9201 - accuracy: 0.6131
# Epoch 8/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.8868 - accuracy: 0.6314
# Epoch 9/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.8573 - accuracy: 0.6204
# Epoch 10/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.8511 - accuracy: 0.6314
# Epoch 11/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.8239 - accuracy: 0.6460
# Epoch 12/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.7976 - accuracy: 0.6496
# Epoch 13/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7979 - accuracy: 0.6350
# Epoch 14/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7719 - accuracy: 0.6606
# Epoch 15/50
# 9/9 [==============================] - 0s 46ms/step - loss: 0.7527 - accuracy: 0.6788
# Epoch 16/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7516 - accuracy: 0.6715
# Epoch 17/50
# 9/9 [==============================] - 0s 46ms/step - loss: 0.7494 - accuracy: 0.6423
# Epoch 18/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7287 - accuracy: 0.6861
# Epoch 19/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.7245 - accuracy: 0.7044
# Epoch 20/50
# 9/9 [==============================] - 0s 53ms/step - loss: 0.7189 - accuracy: 0.6971
# Epoch 21/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.7101 - accuracy: 0.6788
# Epoch 22/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6989 - accuracy: 0.6971
# Epoch 23/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6995 - accuracy: 0.7007
# Epoch 24/50
# 9/9 [==============================] - 0s 47ms/step - loss: 0.6825 - accuracy: 0.7080
# Epoch 25/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6814 - accuracy: 0.7007
# Epoch 26/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6820 - accuracy: 0.6898
# Epoch 27/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.6686 - accuracy: 0.6934
# Epoch 28/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.6538 - accuracy: 0.6934
# Epoch 29/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6545 - accuracy: 0.7445
# Epoch 30/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.6515 - accuracy: 0.7226
# Epoch 31/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.6376 - accuracy: 0.7372
# Epoch 32/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.6428 - accuracy: 0.7153
# Epoch 33/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6254 - accuracy: 0.7555
# Epoch 34/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.6236 - accuracy: 0.7555
# Epoch 35/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6220 - accuracy: 0.7445
# Epoch 36/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6216 - accuracy: 0.7372
# Epoch 37/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6138 - accuracy: 0.7482
# Epoch 38/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6009 - accuracy: 0.7737
# Epoch 39/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.6090 - accuracy: 0.7774
# Epoch 40/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.5912 - accuracy: 0.7701
# Epoch 41/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.5982 - accuracy: 0.7664
# Epoch 42/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.5898 - accuracy: 0.7701
# Epoch 43/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.5812 - accuracy: 0.7956
# Epoch 44/50
# 9/9 [==============================] - 0s 49ms/step - loss: 0.5793 - accuracy: 0.7737
# Epoch 45/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.5723 - accuracy: 0.7701
# Epoch 46/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.5728 - accuracy: 0.7810
# Epoch 47/50
# 9/9 [==============================] - 0s 51ms/step - loss: 0.5821 - accuracy: 0.7409
# Epoch 48/50
# 9/9 [==============================] - 0s 53ms/step - loss: 0.5794 - accuracy: 0.7774
# Epoch 49/50
# 9/9 [==============================] - 0s 50ms/step - loss: 0.5594 - accuracy: 0.8175
# Epoch 50/50
# 9/9 [==============================] - 0s 48ms/step - loss: 0.5543 - accuracy: 0.8102

# %%
# plot loss
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
ax[0].plot(hist_etiology.history['loss'], color='red')
ax[0].set_title('Binary Cross Entropy Loss')
ax[0].set_xlabel("epoch")
ax[0].set_ylabel("loss")

 # plot accuracy
ax[1].set_title('Classification accuracy')
ax[1].plot(hist_etiology.history['accuracy'], color='green', label='train')
ax[1].set_xlabel("epoch")
ax[1].set_ylabel("accuracy")
fig.suptitle("Training error and accuracy in 50 epochs for etiology", fontsize = 20)
fig.tight_layout()
fig.savefig("Etiology.png")
plt.show()

# %% [markdown]
# #### K-fold evaluation of etiology classification

# %%
# evaluate a model using k-fold cross-validation

def evaluate_model_etiology(dataX, dataY, n_splits=5):
    scores, histories1 = list(), list()
     # prepare cross validation
    skf = StratifiedKFold(n_splits, shuffle=True)
     # enumerate splits
    for train_ix, test_ix in skf.split(dataX, dataY):
     # define model
     #model = define_model()
     # select rows for train and test
         trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
     # fit model
         history = model1.fit(trainX, trainY, epochs=50, verbose=0)
     # evaluate model
         _, acc = model1.evaluate(testX, testY, verbose=0)
         print('> %.3f' % (acc * 100.0))
     # stores scores
         scores.append(acc)
         histories1.append(history)
    return scores, histories1

# %%
scores, histories1 = evaluate_model_etiology(dataX, dataY, n_splits=5)
# Out:
# > 83.636
# > 89.091
# > 90.909
# > 96.364
# > 100.000

# %%
summarize_diagnostics(histories1)
